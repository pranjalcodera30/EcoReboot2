# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjalcodera30/EcoReboot2/blob/main/Deep%20Learning%20for%20OFDM%20Signal%20Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow==2.16.2 --quiet
# !pip install --upgrade ml-dtypes --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.8/590.8 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 89.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# %cd /content/drive/MyDrive/dataset/DNN_detection_via_keras
# Out:
# /content/drive/MyDrive/dataset/DNN_detection_via_keras

# %%
# !python /content/drive/MyDrive/dataset/DNN_detection_via_keras/main.py
# Out:
# 2026-05-04 07:23:35.236538: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-04 07:23:35.244100: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-04 07:23:35.269469: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-04 07:23:35.317446: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-04 07:23:35.317531: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip uninstall jax jaxlib ml-dtypes -y
# !pip install ml-dtypes==0.5.1
# !pip install tensorflow
# Out:
# Found existing installation: jax 0.7.2
# Uninstalling jax-0.7.2:
#   Successfully uninstalled jax-0.7.2
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
#   Successfully uninstalled jaxlib-0.7.2
# Found existing installation: ml_dtypes 0.5.4
# Uninstalling ml_dtypes-0.5.4:
#   Successfully uninstalled ml_dtypes-0.5.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 84.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.1.2 requires jaxlib>=0.1.51, which is not installed.
# tensorflow 2.16.2 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tf-keras 2.20.0 requires tensorflow<2.21,>=2.20, but you have tensorflow 2.16.2 which is incompatible.
# ...

# %%
# !pip uninstall -y tensorflow numpy ml-dtypes keras
# Out:
# Found existing installation: tensorflow 2.16.2
# Uninstalling tensorflow-2.16.2:
#   Successfully uninstalled tensorflow-2.16.2
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: ml-dtypes 0.3.2
# Uninstalling ml-dtypes-0.3.2:
#   Successfully uninstalled ml-dtypes-0.3.2
# Found existing installation: keras 3.13.2
# Uninstalling keras-3.13.2:
#   Successfully uninstalled keras-3.13.2

# %%
# !pip install numpy==1.26.4 tensorflow==2.15 keras==2.15 ml-dtypes==0.2.0 --quiet
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.15

# %%
# !pip install numpy==1.26.4 --force-reinstall --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.1.2 requires jaxlib>=0.1.51, which is not installed.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# orbax-checkpoint 0.11.36 requires jax>=0.6.0, which is not installed.
# keras-hub 0.26.0 requires keras>=3.13, which is not installed.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, which is not installed.
# flax 0.11.2 requires jax>=0.6.0, which is not installed.
# tensorstore 0.1.82 requires ml_dtypes>=0.5.0, which is not installed.
# optax 0.2.8 requires jax>=0.5.3, which is not installed.
# optax 0.2.8 requires jaxlib>=0.5.3, which is not installed.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# ...

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
# !pip uninstall -y numpy
# !pip install numpy tensorflow keras # Reinstall numpy, tensorflow and keras to ensure compatibility
from keras import Input, Model
from keras.layers import Dense, BatchNormalization

inputs = Input(shape=(128,))
x = BatchNormalization()(inputs)
x = Dense(64, activation='relu')(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(2, activation='softmax')(x)

model = Model(inputs, outputs)
model.summary()
# Out:
# ...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.save_weights('/content/drive/MyDrive/dataset/DNN_detection_via_keras/final_trained.weights.h5')

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# ----------------------------------------
# 1. LOAD BER VALUES
# ----------------------------------------
mat = sio.loadmat("/content/drive/MyDrive/dataset/DNN_detection_via_keras/BER.mat")   # <-- YOUR uploaded file
BER = mat["BER"].flatten()

print("Loaded BER:", BER)

# Deep Learning CR=1
DL_CR1 = BER

# SNR values
snr_values = np.array([5, 10, 15, 20, 25])

# ----------------------------------------
# 2. Dummy LS/MMSE curves (replace later)
# ----------------------------------------
LS_64  = np.array([1e-1, 5e-2, 2e-2, 1e-2, 5e-3])
MMSE_64 = np.array([8e-2, 3e-2, 1e-2, 5e-3, 2e-3])

LS_8  = np.array([2e-1, 1.2e-1, 8e-2, 4e-2, 1e-2])
MMSE_8 = np.array([1.8e-1, 1e-1, 6e-2, 3e-2, 8e-3])

DL_8 = DL_CR1 * 1.5      # (Example scaling — replace with real values later)

# ----------------------------------------
# 3. Plot 6 curves
# ----------------------------------------
plt.figure(figsize=(7,5))

plt.semilogy(snr_values, DL_CR1, marker='o', label="Deep Learning (64 pilots)")
plt.semilogy(snr_values, LS_64, marker='s', label="LS (64 pilots)")
plt.semilogy(snr_values, MMSE_64, marker='^', label="MMSE (64 pilots)")

plt.semilogy(snr_values, DL_8, marker='o', linestyle='--', label="Deep Learning (8 pilots)")
plt.semilogy(snr_values, LS_8, marker='s', linestyle='--', label="LS (8 pilots)")
plt.semilogy(snr_values, MMSE_8, marker='^', linestyle='--', label="MMSE (8 pilots)")

plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.title("BER curves of deep learning based approach and traditional methods.")
plt.grid(True, which="both")
plt.legend()
plt.ylim([1e-4, 1])
plt.xlim([0, 30])
plt.figure(figsize=(4,4))
plt.show()
# Out:
# Loaded BER: [0.12207031 0.04492188 0.01171875 0.00634766 0.        ]

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------------------
# 1. SNR values
# ----------------------------------------
snr_values = np.array([5, 10, 15, 20, 25])

# ----------------------------------------
# 2. BER values (without CP)
# Replace these arrays with your actual simulation results
# ----------------------------------------
# Deep Learning
DL_with_CP    = np.array([1e-1, 5e-2, 2e-2, 1e-2, 5e-3])
DL_without_CP = np.array([2e-1, 8e-2, 3e-2, 1.5e-2, 7e-3])

# LS
LS_without_CP  = np.array([2e-1, 1.2e-1, 8e-2, 4e-2, 1e-2])

# MMSE
MMSE_without_CP = np.array([1.8e-1, 1e-1, 6e-2, 3e-2, 8e-3])

# ----------------------------------------
# 3. Plot BER curves
# ----------------------------------------
plt.figure(figsize=(7,5))

# Deep Learning
plt.semilogy(snr_values, DL_with_CP, marker='o', label="Deep Learning with CP")
plt.semilogy(snr_values, DL_without_CP, marker='o', linestyle='--', label="Deep Learning without CP")

# LS and MMSE (without CP)
plt.semilogy(snr_values, LS_without_CP, marker='s', linestyle='-', label="LS without CP")
plt.semilogy(snr_values, MMSE_without_CP, marker='^', linestyle='-', label="MMSE without CP")

plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.title("BER curves without CP.")
plt.grid(True, which="both")
plt.legend()
plt.ylim([1e-4, 1])
plt.xlim([0, 30])
plt.figure(figsize=(4,4))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

snr_values = np.array([5, 10, 15, 20, 25])

# Deep Learning ideal (smooth exponential → straight line in same slope direction)
DL_ideal = 1e-1 * np.exp(-0.3 * (snr_values - 5))  # smooth decay

# Other curves (example)
DL_CR1 = np.array([2e-1, 8e-2, 3e-2, 1.5e-2, 7e-3])
MMSE_ideal = np.array([5e-2, 2e-2, 8e-3, 3e-3, 1e-3])
MMSE_CR1 = np.array([8e-2, 3e-2, 1e-2, 5e-3, 2e-3])

plt.figure(figsize=(6,4))  # slightly smaller figure
plt.semilogy(snr_values, DL_ideal, marker='o', linestyle='-', label="Deep Learning (Ideal)")
plt.semilogy(snr_values, DL_CR1, marker='o', linestyle='--', label="Deep Learning (CR=1, clipped)")
plt.semilogy(snr_values, MMSE_ideal, marker='^', linestyle='-', label="MMSE (Ideal)")
plt.semilogy(snr_values, MMSE_CR1, marker='^', linestyle='--', label="MMSE (CR=1, clipped)")

plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.title("BER curves with clipping noise")
plt.grid(True, which="both")
plt.legend()
plt.ylim([1e-4, 1])
plt.xlim([0, 30])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------------------
# 1. SNR values
# ----------------------------------------
snr_values = np.array([5, 10, 15, 20, 25])

# ----------------------------------------
# 2. BER values
# Trained curve: straight line on semilog plot
# Exponential decay -> straight line on semilog
# ----------------------------------------
# DNN trained on Max Delay=16, Paths=24
BER_trained = 1e-1 * np.exp(-0.3 * (snr_values - snr_values[0]))  # smooth exponential decay

# Deployment mismatch scenarios (dummy, less ideal)
BER_paths12 = np.array([2e-1, 8e-2, 3e-2, 1.5e-2, 7e-3])
BER_paths36 = np.array([3e-1, 1.2e-1, 5e-2, 2e-2, 1e-2])
BER_maxdelay24 = np.array([4e-1, 1.5e-1, 6e-2, 2.5e-2, 1.2e-2])

# ----------------------------------------
# 3. Plot BER curves
# ----------------------------------------
plt.figure(figsize=(7,5))

plt.semilogy(snr_values, BER_trained, marker='o', linestyle='-', label="Trained: Max Delay=16, Paths=24")
plt.semilogy(snr_values, BER_paths12, marker='s', linestyle='--', label="Test: Max Delay=16, Paths=12")
plt.semilogy(snr_values, BER_paths36, marker='^', linestyle='--', label="Test: Max Delay=16, Paths=36")
plt.semilogy(snr_values, BER_maxdelay24, marker='d', linestyle='--', label="Test: Max Delay=24, Paths=24")

plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.title("BER Curves: Training vs Deployment Mismatches")
plt.grid(True, which="both")
plt.legend()
plt.ylim([1e-4, 1])
plt.xlim([0, 30])
plt.figure(figsize=(4,4))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------------------
# 1. SNR values
# ----------------------------------------
snr_values = np.array([5, 10, 15, 20, 25])

# ----------------------------------------
# 2. BER values
# ----------------------------------------
# Deep Learning ideal (10^-1 to 10^-3)
DL_ideal = 10**(np.linspace(-1, -3, len(snr_values)))  # smooth straight line

# Deep Learning with all adversities (example)
DL_all_effects = np.array([5e-2, 2e-2, 8e-3, 3e-3, 1e-3])

# MMSE with all adversities (example)
MMSE_all_effects = np.array([8e-2, 3e-2, 1e-2, 5e-3, 2e-3])

# ----------------------------------------
# 3. Plot BER curves
# ----------------------------------------
plt.figure(figsize=(7,5))

plt.semilogy(snr_values, DL_ideal, marker='o', linestyle='-', label="Deep Learning (Ideal)")
plt.semilogy(snr_values, DL_all_effects, marker='o', linestyle='--', label="Deep Learning (All Effects)")
plt.semilogy(snr_values, MMSE_all_effects, marker='^', linestyle='--', label="MMSE (All Effects)")

plt.xlabel("SNR (dB)")
plt.ylabel("BER")
plt.title("BER Curves: Deep Learning vs MMSE with Combined Adversities")
plt.grid(True, which="both")
plt.legend()
plt.ylim([1e-4, 1])
plt.xlim([0, 30])
plt.figure(figsize=(4,4))
plt.show()

# %%
from PIL import Image
import numpy as np
import os

# Create 20 samples of 28x28 pixels
dataset = np.random.randint(0, 256, size=(100, 28, 28), dtype=np.uint8)

# Create the directory if it doesn't exist
output_dir = "dataset_images"
os.makedirs(output_dir, exist_ok=True)

for i, sample in enumerate(dataset):
    img = Image.fromarray(sample)          # Convert array to image
    img = img.resize((112, 112), Image.NEAREST)  # Resize to 112x112
    img.save(f"{output_dir}/sample_{i}.png")
